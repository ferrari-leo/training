# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright Pierian Data</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Time Series with Pandas Project Exercise
#
# For this exercise, answer the questions below given the dataset: https://fred.stlouisfed.org/series/UMTMVS
#
# This dataset is the Value of Manufacturers' Shipments for All Manufacturing Industries.

# %% [markdown]
# **Import any necessary libraries.**

# %%
# CODE HERE
import os
import pandas as pd

# %% [markdown]
# **Read in the data UMTMVS.csv file from the Data folder**

# %%
# CODE HERE
dir_data = '/Users/IFLM/Desktop/vsc/training/time_series_python/data'
df = pd.read_csv(os.path.join(dir_data, 'UMTMVS.csv'))

# %% [markdown]
# **Check the head of the data**

# %%
# CODE HERE
df.head()
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %%
# Out:
#          DATE    UMTMVS
# 0  1992-01-01  209438.0
# 1  1992-02-01  232679.0
# 2  1992-03-01  249673.0
# 3  1992-04-01  239666.0
# 4  1992-05-01  243231.0

# %% [markdown]
# **Set the DATE column as the index.**

# %%
# CODE HERE
df.set_index('DATE', inplace=True)
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %% [markdown]
# **Check the data type of the index.**

# %%
# CODE HERE
df.index
# Out:
# Index(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#        '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01', '1992-10-01',
#        ...
#        '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#        '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01'],
#       dtype='object', name='DATE', length=325)

# %%
# Out:
# Index(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#        '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01', '1992-10-01',
#        ...
#        '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#        '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01'],
#       dtype='object', name='DATE', length=325)

# %% [markdown]
# **Convert the index to be a datetime index. Note, there are many, many correct ways to do this!**

# %%
# CODE HERE
df.index = pd.to_datetime(df.index)
df.index
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %%
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %% [markdown]
# **Plot out the data, choose a reasonable figure size**

# %%
# CODE HERE
df.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# **What was the percent increase in value from Jan 2009 to Jan 2019?**

# %%
#CODE HERE
100*(df.loc['2019-01-01','UMTMVS']/df.loc['2009-01-01','UMTMVS']-1)
# Out:
# 38.47214929650165

# %%
# Out:
# UMTMVS    38.472149
# dtype: float64

# %% [markdown]
# **What was the percent decrease from Jan 2008 to Jan 2009?**

# %%
#CODE HERE
100*(df.loc['2009-01-01','UMTMVS']/df.loc['2008-01-01','UMTMVS']-1)
# Out:
# -22.02277548131305

# %%
# Out:
# UMTMVS   -22.022775
# dtype: float64

# %% [markdown]
# **What is the month with the least value after 2005?** [HINT](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.idxmin.html)

# %%
#CODE HERE
df.loc['2005-01-01':,'UMTMVS'].sort_values()
# Out:
# DATE
# 2009-01-01    337101.0
# 2009-02-01    340896.0
# 2005-01-01    346845.0
# 2009-04-01    354790.0
# 2009-07-01    358332.0
#                 ...
# 2018-09-01    516992.0
# 2018-03-01    518285.0
# 2018-06-01    525660.0
# 2018-10-01    527031.0
# 2018-08-01    529157.0
# Name: UMTMVS, Length: 169, dtype: float64

# %%
# Out:
# UMTMVS   2009-01-01
# dtype: datetime64[ns]

# %% [markdown]
# **What 6 months have the highest value?**

# %%
# CODE HERE
df.sort_values(by='UMTMVS', ascending=False).head(6)
# Out:
#               UMTMVS
# DATE
# 2018-08-01  529157.0
# 2018-10-01  527031.0
# 2018-06-01  525660.0
# 2018-03-01  518285.0
# 2018-09-01  516992.0
# 2014-06-01  516935.0

# %%
# Out:
#               UMTMVS    Yearly Mean
# DATE
# 2018-08-01  529157.0  490453.500000
# 2018-10-01  527031.0  496482.333333
# 2018-06-01  525660.0  483611.000000
# 2018-03-01  518285.0  474351.250000
# 2018-09-01  516992.0  493075.583333

# %% [markdown]
# **How many millions of dollars in value was lost in 2008? (Another way of posing this question is what was the value difference between Jan 2008 and Jan 2009)**

# %%
# CODE HERE
df.loc['2009-01-01','UMTMVS']-df.loc['2008-01-01','UMTMVS']
# Out:
# -95206.0

# %%
# Out:
# UMTMVS    95206.0
# dtype: float64

# %% [markdown]
# **Create a bar plot showing the average value in millions of dollars per year**

# %%
# CODE HERE
df['UMTMVS'].resample(rule='Y').mean().plot.bar()
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# **What year had the biggest increase in mean value from the previous year's mean value? (Lots of ways to get this answer!)**
#
# [HINT for a useful method](https://pandas.pydata.org/pandas-docs/version/0.21/generated/pandas.DataFrame.idxmax.html)

# %%
# CODE HERE
df_y = pd.DataFrame()
df_y['annual mean'] = df['UMTMVS'].resample(rule='Y').mean()
df_y['annual mean diff'] = df_y['annual mean'] - df_y['annual mean'].shift(1)
df_y.sort_values(by='annual mean diff', ascending = False)
# Out:
#               annual mean  annual mean diff
# DATE
# 2011-12-31  457657.833333      48384.750000
# 2010-12-31  409273.083333      40624.833333
# 2005-12-31  395173.083333      36092.250000
# 2018-12-31  499964.166667      32887.833333
# 2007-12-31  443288.083333      25325.416667
# 2004-12-31  359080.833333      24465.166667
# 2006-12-31  417962.666667      22789.583333
# 2017-12-31  467076.333333      20851.833333
# 1995-12-31  289973.083333      20130.416667
# 1997-12-31  319558.250000      19792.583333
# 1994-12-31  269842.666667      18134.583333
# 2012-12-31  474727.333333      17069.500000
# 2000-12-31  350715.333333      14724.750000
# 2008-12-31  455749.500000      12461.416667
# 1999-12-31  335990.583333      11006.166667
# 1996-12-31  299765.666667       9792.583333
# 1993-12-31  251708.083333       9706.083333
# 2013-12-31  484145.416667       9418.083333
# 2003-12-31  334615.666667       8388.750000
# 2014-12-31  490629.916667       6484.500000
# ...

# %%
# Out:
#                    UMTMVS
# DATE
# 1992-12-31  242002.000000
# 1993-12-31  251708.083333
# 1994-12-31  269842.666667
# 1995-12-31  289973.083333
# 1996-12-31  299765.666667

# %%
# Out:
# Timestamp('2011-12-31 00:00:00', freq='A-DEC')

# %% [markdown]
# **Plot out the yearly rolling mean on top of the original data. Recall that this is monthly data and there are 12 months in a year!**

# %%
# CODE HERE

df['annual mean'] = df['UMTMVS'].rolling(12).mean()
df.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='DATE'>

# %% [markdown]
# **BONUS QUESTION (HARD).**
#
# **Some month in 2008 the value peaked for that year. How many months did it take to surpass that 2008 peak? (Since it crashed immediately after this peak) There are many ways to get this answer. NOTE: I get 70 months as my answer, you may get 69 or 68, depending on whether or not you count the start and end months. Refer to the video solutions for full explanation on this.**

# %%
#CODE HERE
max_2008_month = df.loc['2008-01-01':'2008-12-01','UMTMVS'].idxmax()
df_post_2008_max = df[max_2008_month:]
first_surpass = (df_post_2008_max['UMTMVS'] > df.loc[max_2008_month,'UMTMVS']).idxmax()
len(df[max_2008_month:first_surpass])
# Out:
# 70

# %%
# Out:
# 70

# %% [markdown]
# # GREAT JOB!
